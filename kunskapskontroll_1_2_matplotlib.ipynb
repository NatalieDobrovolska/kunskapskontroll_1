# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %% [markdown]
# It can be done in object oriented method or MATLAB style. The recommended approach is object oriented method. In this way the code can be more precise, it´s easier to reuse the code in the same coding. Better controll over coding.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
# Figure can be seen as a canvas that stores all elements
# Axes is a part of figure where data can be plotted
# Axis is lines and ticks representing the scale and labels along the axes
# An artist is everything visible, like text, lines

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
# Numpy arrays or objects that can be transformed into numpy arrays

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
# Object oriented approach

fig, ax = plt.subplots()
x = np.linspace(-4,4)
y = x**2
ax.plot(x, y)
ax.set_title ("My first plot")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
print(y)
# Out:
# [1.60000000e+01 1.47205331e+01 1.34943773e+01 1.23215327e+01
#  1.12019992e+01 1.01357768e+01 9.12286547e+00 8.16326531e+00
#  7.25697626e+00 6.40399833e+00 5.60433153e+00 4.85797584e+00
#  4.16493128e+00 3.52519783e+00 2.93877551e+00 2.40566431e+00
#  1.92586422e+00 1.49937526e+00 1.12619742e+00 8.06330696e-01
#  5.39775094e-01 3.26530612e-01 1.66597251e-01 5.99750104e-02
#  6.66389005e-03 6.66389005e-03 5.99750104e-02 1.66597251e-01
#  3.26530612e-01 5.39775094e-01 8.06330696e-01 1.12619742e+00
#  1.49937526e+00 1.92586422e+00 2.40566431e+00 2.93877551e+00
#  3.52519783e+00 4.16493128e+00 4.85797584e+00 5.60433153e+00
#  6.40399833e+00 7.25697626e+00 8.16326531e+00 9.12286547e+00
#  1.01357768e+01 1.12019992e+01 1.23215327e+01 1.34943773e+01
#  1.47205331e+01 1.60000000e+01]

# %%
# Pyplot approach

x = np.linspace(-4,4)
y = x**2
plt.plot(x, y)
plt.title("My first plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
print(y)
# Out:
# [1.60000000e+01 1.47205331e+01 1.34943773e+01 1.23215327e+01
#  1.12019992e+01 1.01357768e+01 9.12286547e+00 8.16326531e+00
#  7.25697626e+00 6.40399833e+00 5.60433153e+00 4.85797584e+00
#  4.16493128e+00 3.52519783e+00 2.93877551e+00 2.40566431e+00
#  1.92586422e+00 1.49937526e+00 1.12619742e+00 8.06330696e-01
#  5.39775094e-01 3.26530612e-01 1.66597251e-01 5.99750104e-02
#  6.66389005e-03 6.66389005e-03 5.99750104e-02 1.66597251e-01
#  3.26530612e-01 5.39775094e-01 8.06330696e-01 1.12619742e+00
#  1.49937526e+00 1.92586422e+00 2.40566431e+00 2.93877551e+00
#  3.52519783e+00 4.16493128e+00 4.85797584e+00 5.60433153e+00
#  6.40399833e+00 7.25697626e+00 8.16326531e+00 9.12286547e+00
#  1.01357768e+01 1.12019992e+01 1.23215327e+01 1.34943773e+01
#  1.47205331e+01 1.60000000e+01]

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

#Pyplot approach

#scatter plot
plt.subplot(1, 2, 1)
plt.scatter(random_data_x, random_data_y)
plt.title ("My second plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")


#barplot
plt.subplot(1, 2, 2)
plt.bar(names, values)
plt.title("My third plot")
plt.xlabel("Fruits")
plt.ylabel("Quantity")

plt.tight_layout()

# %%
# Object oriented approach

fig, axs = plt.subplots(1, 2)
axs[0].scatter(random_data_x, random_data_y)
axs[0].set_title("My second plot")
axs[1].bar(names, values)
axs[1].set_title("My third plot")
# Out:
# Text(0.5, 1.0, 'My third plot')
